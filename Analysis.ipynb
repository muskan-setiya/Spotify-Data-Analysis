# %% [markdown]
# **GROUP NO. 2**
#
# **MEMBERS:-**
#
#     NAME                          ROLL NO.
#
#
# ```
# 1)Arya Harde                    03
#
# 2)Devyani Kalamkar              04
#
# 3)Muskan Setiya                 10
#
# 4)Sanskriti Gupta               15
# ```

# %% [markdown]
# #Configure and Overview of Spotify.csv

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls '/content/drive/MyDrive/Untitled folder/Spotify.csv'
# Out:
# '/content/drive/MyDrive/Untitled folder/Spotify.csv'

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/Untitled folder/Spotify.csv')

# %%
df.columns
# Out:
# Index(['artist', 'song', 'duration_ms', 'explicit', 'year', 'popularity',
#        'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'genre'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1941 entries, 0 to 1999
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   artist            1941 non-null   object
#  1   song              1941 non-null   object
#  2   duration_ms       1941 non-null   int64
#  3   explicit          1941 non-null   bool
#  4   year              1941 non-null   int64
#  5   popularity        1941 non-null   int64
#  6   danceability      1941 non-null   float64
#  7   energy            1941 non-null   float64
#  8   key               1941 non-null   int64
#  9   loudness          1941 non-null   float64
#  10  mode              1941 non-null   int64
#  11  speechiness       1941 non-null   float64
#  12  acousticness      1941 non-null   float64
#  13  instrumentalness  1941 non-null   float64
#  14  liveness          1941 non-null   float64
#  15  valence           1941 non-null   float64
# ...

# %%
print("No. of rows: ",df.shape[0])
# Out:
# No. of rows:  1941

# %%
print("No. of columns: ",df.shape[1])
# Out:
# No. of columns:  18

# %%
df.head(10)
# Out:
#             artist                    song  duration_ms  explicit  year  \
# 0   Britney Spears  Oops!...I Did It Again       211160     False  2000
# 1        blink-182    All The Small Things       167066     False  1999
# 2       Faith Hill                 Breathe       250546     False  1999
# 3         Bon Jovi            It's My Life       224493     False  2000
# 4           *NSYNC             Bye Bye Bye       200560     False  2000
# 5            Sisqo              Thong Song       253733      True  1999
# 6           Eminem     The Real Slim Shady       284200      True  2000
# 7  Robbie Williams                 Rock DJ       258560     False  2000
# 8  Destiny's Child             Say My Name       271333     False  1999
# 9            Modjo  Lady - Hear Me Tonight       307153     False  2001
#
#    popularity  danceability  energy  key  loudness  mode  speechiness  \
# 0          77         0.751   0.834    1    -5.444     0       0.0437
# ...

# %%
#checking for null values
df.isnull()
# Out:
#       artist   song  duration_ms  explicit   year  popularity  danceability  \
# 0      False  False        False     False  False       False         False
# 1      False  False        False     False  False       False         False
# 2      False  False        False     False  False       False         False
# 3      False  False        False     False  False       False         False
# 4      False  False        False     False  False       False         False
# ...      ...    ...          ...       ...    ...         ...           ...
# 1995   False  False        False     False  False       False         False
# 1996   False  False        False     False  False       False         False
# 1997   False  False        False     False  False       False         False
# 1998   False  False        False     False  False       False         False
# 1999   False  False        False     False  False       False         False
#
# ...

# %%
#counting null values
print(df.isnull().sum())
# Out:
# artist              0
# song                0
# duration_ms         0
# explicit            0
# year                0
# popularity          0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# genre               0
# dtype: int64

# %% [markdown]
# Therefore, we can say that null values are not present in this dataset.

# %%
#checking duplicated data
df.duplicated().sum()
# Out:
# 59

# %%
#Look for duplicates
print(df.drop_duplicates(inplace = True))
# Out:
# None

# %%
#after removing duplicated rows 
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #Statistical Analysis

# %%
(df['year']>2010).sum()
# Out:
# 893

# %%
df.describe()
# Out:
#          duration_ms         year   popularity  danceability       energy  \
# count    1941.000000  1941.000000  1941.000000   1941.000000  1941.000000
# mean   228594.973725  2009.520350    59.633179      0.667814     0.721549
# std     39249.796103     5.875532    21.501053      0.140608     0.152872
# min    113000.000000  1998.000000     0.000000      0.129000     0.054900
# 25%    203506.000000  2004.000000    56.000000      0.581000     0.624000
# 50%    223186.000000  2010.000000    65.000000      0.676000     0.739000
# 75%    247946.000000  2015.000000    73.000000      0.765000     0.840000
# max    484146.000000  2020.000000    89.000000      0.975000     0.999000
#
#                key     loudness         mode  speechiness  acousticness  \
# count  1941.000000  1941.000000  1941.000000  1941.000000   1941.000000
# mean      5.369397    -5.514082     0.553323     0.103783      0.128173
# std       3.615270     1.938950     0.497277     0.096148      0.172584
# ...

# %%
df.mode()
# Out:
#     artist   song  duration_ms explicit    year  popularity  danceability  \
# 0    Drake  Sorry       185586    False  2012.0         0.0         0.687
# 1  Rihanna    NaN       200106      NaN     NaN         NaN         0.791
# 2      NaN    NaN       212106      NaN     NaN         NaN           NaN
# 3      NaN    NaN       212360      NaN     NaN         NaN           NaN
# 4      NaN    NaN       221226      NaN     NaN         NaN           NaN
# 5      NaN    NaN       222653      NaN     NaN         NaN           NaN
# 6      NaN    NaN       243533      NaN     NaN         NaN           NaN
# 7      NaN    NaN       268866      NaN     NaN         NaN           NaN
#
#    energy  key  loudness  mode  speechiness  acousticness  instrumentalness  \
# 0   0.783  1.0    -6.366   1.0       0.0290         0.107               0.0
# 1     NaN  NaN       NaN   NaN       0.0432         0.150               NaN
# ...

# %%
#VARIANCE
df.var()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# duration_ms         1.540546e+09
# explicit            2.002231e-01
# year                3.452188e+01
# popularity          4.622953e+02
# danceability        1.977069e-02
# energy              2.336973e-02
# key                 1.307018e+01
# loudness            3.759529e+00
# mode                2.472841e-01
# speechiness         9.244407e-03
# acousticness        2.978518e-02
# instrumentalness    7.809499e-03
# liveness            1.985550e-02
# valence             4.877268e-02
# tempo               7.284857e+02
# dtype: float64

# %%
#STANDARD DEVIATION
df.std()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# duration_ms         39249.796103
# explicit                0.447463
# year                    5.875532
# popularity             21.501053
# danceability            0.140608
# energy                  0.152872
# key                     3.615270
# loudness                1.938950
# mode                    0.497277
# speechiness             0.096148
# acousticness            0.172584
# instrumentalness        0.088371
# liveness                0.140910
# valence                 0.220845
# tempo                  26.990475
# dtype: float64

# %%
#COVARIANCE
df.cov()
# Out:
#                    duration_ms     explicit          year    popularity  \
# duration_ms       1.540546e+09  2100.646448 -73527.704362  40626.014584
# explicit          2.100646e+03     0.200223      0.203388      0.455146
# year             -7.352770e+04     0.203388     34.521879     -0.921397
# popularity        4.062601e+04     0.455146     -0.921397    462.295270
# danceability     -3.315870e+02     0.015339      0.029282     -0.000433
# energy           -4.979058e+02    -0.011233     -0.099040     -0.044057
# key              -1.920171e+02     0.002904      0.182427      1.054129
# loudness         -6.562059e+03    -0.079182      0.196269      1.269055
# mode             -7.992154e+01     0.011271     -0.021060     -0.207749
# speechiness       2.360062e+02     0.017874      0.001777      0.045434
# acousticness      6.746824e+01    -0.002165      0.041269      0.083495
# instrumentalness -2.223019e+01    -0.003266     -0.026735     -0.091401
# ...

# %%
#CORRELATION
df.corr()
# Out:
#                   duration_ms  explicit      year  popularity  danceability  \
# duration_ms          1.000000  0.119608 -0.318835    0.048140     -0.060083
# explicit             0.119608  1.000000  0.077361    0.047308      0.243799
# year                -0.318835  0.077361  1.000000   -0.007294      0.035444
# popularity           0.048140  0.047308 -0.007294    1.000000     -0.000143
# danceability        -0.060083  0.243799  0.035444   -0.000143      1.000000
# energy              -0.082982 -0.164212 -0.110265   -0.013404     -0.103204
# key                 -0.001353  0.001795  0.008588    0.013561      0.035747
# loudness            -0.086226 -0.091265  0.017228    0.030441     -0.035638
# mode                -0.004095  0.050653 -0.007208   -0.019430     -0.068643
# speechiness          0.062538  0.415445  0.003146    0.021977      0.140955
# acousticness         0.009960 -0.028032  0.040698    0.022501     -0.062374
# ...

# %%
#Top 10 artists with most no. of popular songs
print("Top 10 artists with most popular songs:-")
df.artist.value_counts().head(10)
# Out:
# Top 10 artists with most popular songs:-
# Drake             23
# Rihanna           23
# Eminem            21
# Calvin Harris     20
# Britney Spears    19
# David Guetta      18
# Chris Brown       16
# Katy Perry        16
# Taylor Swift      16
# Beyoncé           16
# Name: artist, dtype: int64

# %%
#Last 10 artists with least no. of popular songs
print("Last 10 artists with least popular songs:-")
df.artist.value_counts().tail(10)
# Out:
# Last 10 artists with least popular songs:-
# Sophie Ellis-Bextor    1
# Lucenzo                1
# Duck Sauce             1
# A1                     1
# INNA                   1
# Big Tymers             1
# DJ Sammy               1
# Cam’ron                1
# Mumford & Sons         1
# Blanco Brown           1
# Name: artist, dtype: int64

# %%
#genres:-
df.genre.unique()
# Out:
# array(['pop', 'rock, pop', 'pop, country', 'rock, metal',
#        'hip hop, pop, R&B', 'hip hop', 'pop, rock', 'pop, R&B',
#        'Dance/Electronic', 'pop, Dance/Electronic',
#        'rock, Folk/Acoustic, easy listening', 'metal', 'hip hop, pop',
#        'R&B', 'pop, latin', 'Folk/Acoustic, rock',
#        'pop, easy listening, Dance/Electronic', 'rock',
#        'rock, blues, latin', 'pop, rock, metal', 'rock, pop, metal',
#        'hip hop, R&B', 'pop, Folk/Acoustic', 'set()',
#        'hip hop, pop, latin', 'hip hop, Dance/Electronic',
#        'hip hop, pop, rock', 'World/Traditional, Folk/Acoustic',
#        'Folk/Acoustic, pop', 'rock, easy listening',
#        'World/Traditional, hip hop', 'hip hop, pop, R&B, latin',
#        'rock, blues', 'rock, R&B, Folk/Acoustic, pop', 'latin',
#        'pop, R&B, Dance/Electronic', 'World/Traditional, rock',
#        'pop, rock, Dance/Electronic', 'pop, easy listening, jazz',
# ...

# %%
#print(df.popularity.sort_values(ascending=False).head(10) , df['song'])
#top 20 songs' artists
df.sort_values('popularity', axis=0, ascending=False)['artist'].head(20)
# Out:
# 1322    The Neighbourhood
# 1311            Tom Odell
# 201                Eminem
# 1819        Billie Eilish
# 1613               WILLOW
# 6                  Eminem
# 1514               Avicii
# 1512    The Neighbourhood
# 1709           Ed Sheeran
# 1999          Post Malone
# 1227           Bruno Mars
# 209                Eminem
# 1905        Gesaffelstein
# 1344       Arctic Monkeys
# 1712        Billie Eilish
# 1408          John Legend
# 1701            Sean Paul
# 1700           Ed Sheeran
# 1511           The Weeknd
# 1910        Lewis Capaldi
# Name: artist, dtype: object

# %%
#Top 20 popular songs
df.sort_values('popularity', axis=0, ascending=False)['song'].head(20)
# Out:
# 1322                        Sweater Weather
# 1311                           Another Love
# 201                              Without Me
# 1819                   lovely (with Khalid)
# 1613                         Wait a Minute!
# 6                       The Real Slim Shady
# 1514                             The Nights
# 1512                           Daddy Issues
# 1709                                Perfect
# 1999                                Circles
# 1227                   Locked out of Heaven
# 209                        'Till I Collapse
# 1905    Lost in the Fire (feat. The Weeknd)
# 1344                       Do I Wanna Know?
# 1712                                  Bored
# 1408                              All of Me
# 1701                                 No Lie
# 1700                           Shape of You
# 1511                              The Hills
# 1910                      Someone You Loved
# Name: song, dtype: object

# %%
#Top 10 popular genres
df.sort_values('popularity', axis=0, ascending=False)['genre'].head(10)
# Out:
# 1322                     rock, pop
# 1311                           pop
# 201                        hip hop
# 1819         pop, Dance/Electronic
# 1613    pop, R&B, Dance/Electronic
# 6                          hip hop
# 1514         pop, Dance/Electronic
# 1512                     rock, pop
# 1709                           pop
# 1999                       hip hop
# Name: genre, dtype: object

# %%
#ROCK,POP SONGS DATAFRAME
top_genres=['rock, pop']
df_genre=df[df.genre.isin(top_genres)]
df_genre
# Out:
#                         artist  \
# 1                    blink-182
# 13                       Sting
# 107            Jimmy Eat World
# 173              Lenny Kravitz
# 190                     Travis
# 206                   No Doubt
# 245                   No Doubt
# 257                   No Doubt
# 269                   Coldplay
# 297                   Coldplay
# 304             Counting Crows
# 371                   No Doubt
# 393                 Switchfoot
# 588              Stereophonics
# 591                   Coldplay
# 596   The All-American Rejects
# 688                 Razorlight
# 694                 Razorlight
# 792     Manic Street Preachers
# 881                   Coldplay
# 889                   Coldplay
# 1090                  Owl City
# 1094                Neon Trees
# 1139                  Coldplay
# 1171         Foster The People
# 1191                  Coldplay
# 1202                      fun.
# 1276                  Owl City
# 1282                  Coldplay
# ...

# %%
#POP SONGS DATAFRAME
top_genres2=['pop']
df_genre2=df[df.genre.isin(top_genres2)]
df_genre2
# Out:
#                artist                                              song  \
# 0      Britney Spears                            Oops!...I Did It Again
# 4              *NSYNC                                       Bye Bye Bye
# 10    Gigi D'Agostino                                  L'Amour Toujours
# 11          Eiffel 65  Move Your Body - Gabry Ponte Original Radio Edit
# 12       Bomfunk MC's                                        Freestyler
# ...               ...                                               ...
# 1985       Ed Sheeran     Cross Me (feat. Chance the Rapper & PnB Rock)
# 1990        Sam Smith                                 How Do You Sleep?
# 1995   Jonas Brothers                                            Sucker
# 1996     Taylor Swift                                      Cruel Summer
# 1998        Sam Smith            Dancing With A Stranger (with Normani)
#
#       duration_ms  explicit  year  popularity  danceability  energy  key  \
# ...

# %%
#hip hop SONGS DATAFRAME
top_genres2=['hip hop']
df_genre2=df[df.genre.isin(top_genres2)]
df_genre2
# Out:
#                   artist                         song  duration_ms  explicit  \
# 6                 Eminem          The Real Slim Shady       284200      True
# 19               Dr. Dre             The Next Episode       161506      True
# 23                M.O.P.                  Cold as Ice       244466      True
# 37                 JAY-Z                  Big Pimpin'       283066      True
# 43               Dr. Dre             Forgot About Dre       222293      True
# ...                  ...                          ...          ...       ...
# 1966            Blueface                     Thotiana       129264      True
# 1967              DaBaby                         Suge       163320      True
# 1975  Tyler, The Creator                    EARFQUAKE       190066      True
# 1994         Post Malone  Goodbyes (Feat. Young Thug)       174960      True
# 1999         Post Malone                      Circles       215280     False
#
# ...

# %%
top_five_genres=['pop','rock','metal','country','hip hop']
df_gen=df[df.genre.isin(top_five_genres)]

# %%
from matplotlib import pyplot as plt
import seaborn as sns
plt.figure(figsize=(6,5))
sns.kdeplot(data=df_gen,x='popularity',hue='genre',multiple='fill',alpha=0.3)
plt.show()

# %%
#Longest duration Songs
df.iloc[df.duration_ms.idxmax()]
# Out:
# artist              O.T. Genasis
# song                        CoCo
# duration_ms               239573
# explicit                    True
# year                        2014
# popularity                    61
# danceability               0.886
# energy                     0.628
# key                            8
# loudness                  -5.949
# mode                           1
# speechiness                0.131
# acousticness             0.00215
# instrumentalness        0.000012
# liveness                    0.31
# valence                    0.178
# tempo                    119.906
# genre               hip hop, pop
# Name: 1424, dtype: object

# %%
# Shortest duration Song
df.iloc[df.duration_ms.idxmin()]
# Out:
# artist                      Sam Smith
# song                How Do You Sleep?
# duration_ms                    202204
# explicit                        False
# year                             2019
# popularity                         73
# danceability                    0.477
# energy                          0.682
# key                                 1
# loudness                       -4.931
# mode                                0
# speechiness                    0.0925
# acousticness                    0.153
# instrumentalness                  0.0
# liveness                       0.0763
# valence                         0.345
# tempo                         110.567
# genre                             pop
# Name: 1990, dtype: object
